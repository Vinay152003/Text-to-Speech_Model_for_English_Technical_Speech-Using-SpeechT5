# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.8 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers

# %%
# !pip install transformers datasets soundfile

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.4/447.4 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 73.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import auth

# Authenticate with Hugging Face Hub
auth.authenticate_user()

# %%
import os

# Set your Hugging Face token
os.environ["HF_TOKEN"] = "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"

# %%
# !pip install tokenizer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.8/112.8 kB 7.7 MB/s eta 0:00:00
# ...

# %%
from transformers import SpeechT5ForTextToSpeech, SpeechT5Processor

# Load the model and processor without authentication
model = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
processor = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/585M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/433 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/232 [00:00<?, ?B/s]
# spm_char.model:   0%|          | 0.00/238k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# ...

# %%
from transformers import SpeechT5ForTextToSpeech, SpeechT5Tokenizer

# Load the pre-trained SpeechT5 model and tokenizer
model = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
tokenizer = SpeechT5Tokenizer.from_pretrained("microsoft/speecht5_tts")

# Fine-tune the model here (not shown in this example)

# Save the model and tokenizer to your specified directory
model.save_pretrained("/content/my_fine_tuned_model")
tokenizer.save_pretrained("/content/my_fine_tuned_model")
# Out:
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 1876}
# ('/content/my_fine_tuned_model/tokenizer_config.json',
#  '/content/my_fine_tuned_model/special_tokens_map.json',
#  '/content/my_fine_tuned_model/spm_char.model',
#  '/content/my_fine_tuned_model/added_tokens.json')

# %%
# !pip install phonemizer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.4/213.4 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.1/562.1 kB 22.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.2/116.2 kB 8.3 MB/s eta 0:00:00
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=445f23cfd9d4c208969d57125a0e53ad63ee16ef0a337322c1c5558164b2dd20
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# ...

# %%
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan
from datasets import load_dataset
import torch
import soundfile as sf

# Load the models
processor = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
model = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# config.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/50.7M [00:00<?, ?B/s]

# %%
import json
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan
from datasets import load_dataset
import torch
import soundfile as sf

# Load pronunciation dictionary from JSON file
with open("/content/pronunciation_dict.json", "r") as f:
    pronunciation_dict = json.load(f)

# Function to preprocess the input text
def preprocess_text(text):
    # Replace terms with phonetic equivalents from the dictionary
    for term, phonetic in pronunciation_dict.items():
        text = text.replace(term, phonetic)
    return text

# Example text with technical terms
input_text = "We used jupyter and no sql for natural language processing with NLP and SQL."

# Preprocess the text using the custom pronunciation dictionary
processed_text = preprocess_text(input_text)
print("Processed Text:", processed_text)

# Load the models
processor = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
model = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")

# Convert the processed text to model inputs
inputs = processor(text=processed_text, return_tensors="pt")

# Load xvector embeddings from dataset for speaker voice characteristics
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

# Generate speech using the model and vocoder
speech = model.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)

# Save the generated speech as a .wav file
sf.write("speech_output.wav", speech.numpy(), samplerate=16000)

# Play the generated audio
from IPython.display import Audio
Audio("speech_output.wav")
# Out:
# Processed Text: We used jupyter and no sql for natural language processing with N L P and S Q L.
# README.md:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# cmu-arctic-xvectors.py:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# 0000.parquet:   0%|          | 0.00/21.3M [00:00<?, ?B/s]
# Generating validation split:   0%|          | 0/7931 [00:00<?, ? examples/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# metrics

# %%
import time

# Measure inference time
start_time = time.time()

# Generate speech using the model and vocoder
speech = model.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)

# Measure end time and calculate the total inference time
end_time = time.time()
inference_time = end_time - start_time
print(f"Inference Time: {inference_time:.2f} seconds")
# Out:
# Inference Time: 16.13 seconds

# %%
import torch.quantization as quant

# Apply dynamic quantization on the model
quantized_model = torch.quantization.quantize_dynamic(
    model,  # Model to quantize
    {torch.nn.Linear},  # Layers to quantize
    dtype=torch.qint8  # Use int8 precision
)

# Test inference speed after quantization
start_time_quantized = time.time()

# Generate speech using the quantized model and vocoder
speech_quantized = quantized_model.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)

end_time_quantized = time.time()
quantized_inference_time = end_time_quantized - start_time_quantized
print(f"Quantized Inference Time: {quantized_inference_time:.2f} seconds")

# Save the quantized generated speech as a .wav file
sf.write("speech_output_quantized.wav", speech_quantized.numpy(), samplerate=16000)
# Out:
# Quantized Inference Time: 5.06 seconds

# %%
# !pip install jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 48.2 MB/s eta 0:00:00
# ...

# %%
import json
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan
from datasets import load_dataset
import torch
import soundfile as sf
from sklearn.metrics import classification_report
from jiwer import wer, cer

# Load pronunciation dictionary from JSON file
with open("/content/pronunciation_dict.json", "r") as f:
    pronunciation_dict = json.load(f)

# Function to preprocess the input text
def preprocess_text(text):
    # Replace terms with their correct forms from the dictionary
    for term in pronunciation_dict.keys():
        text = text.replace(term, term)  # Keep the term intact
    return text

# Example input text with technical terms
input_text = "We used jupyter and no sql for natural language processing with NLP and SQL."

# Preprocess the input text
processed_text = preprocess_text(input_text)
print("Processed Text:", processed_text)

# Load the models
processor = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
model = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")

# Convert the processed text to model inputs
inputs = processor(text=processed_text, return_tensors="pt")

# Load xvector embeddings for speaker voice characteristics
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

# Generate speech using the model and vocoder
speech = model.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)

# Save the generated speech as a .wav file
sf.write("speech_output.wav", speech.numpy(), samplerate=16000)

# Prepare reference text for evaluation
reference_text = "We used jupyter and no sql for natural language processing with NLP and SQL."

# Calculate WER and CER
word_error_rate = wer(reference_text, processed_text)  # Use processed text for prediction
character_error_rate = cer(reference_text, processed_text)

# Print WER and CER
print(f"Word Error Rate (WER): {word_error_rate:.2f}")
print(f"Character Error Rate (CER): {character_error_rate:.2f}")

# Tokenize both texts
reference_tokens = reference_text.split()
predicted_tokens = processed_text.split()  # Ensure to split the processed text

# Print token counts for debugging
print(f"Reference tokens ({len(reference_tokens)}): {reference_tokens}")
print(f"Predicted tokens ({len(predicted_tokens)}): {predicted_tokens}")

# Ensure the lengths are the same
if len(reference_tokens) != len(predicted_tokens):
    print("Warning: The number of tokens in reference and predicted texts do not match!")

# Generate classification report
print("Classification Report (Word-level):")
print(classification_report(reference_tokens, predicted_tokens, zero_division=0))
# Out:
# Processed Text: We used jupyter and no sql for natural language processing with NLP and SQL.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Word Error Rate (WER): 0.00
# Character Error Rate (CER): 0.00
# Reference tokens (14): ['We', 'used', 'jupyter', 'and', 'no', 'sql', 'for', 'natural', 'language', 'processing', 'with', 'NLP', 'and', 'SQL.']
# Predicted tokens (14): ['We', 'used', 'jupyter', 'and', 'no', 'sql', 'for', 'natural', 'language', 'processing', 'with', 'NLP', 'and', 'SQL.']
# Classification Report (Word-level):
#               precision    recall  f1-score   support
#
#          NLP       1.00      1.00      1.00         1
# ...

# %%
import gradio as gr
import json
import torch
import numpy as np
import re
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan
from datasets import load_dataset
import soundfile as sf

# Step 1: Load the models and the pronunciation dictionary
processor = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
model = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")

# Load pronunciation dictionary from JSON file
with open("/content/pronunciation_dict.json", "r") as f:
    pronunciation_dict = json.load(f)

# Function to preprocess and apply pronunciation dictionary
def preprocess_text(text):
    # Convert text to uppercase for uniformity in matching
    text = text.upper()
    for term, phonetic in pronunciation_dict.items():
        # Replace terms with their phonetic equivalents
        text = text.replace(term.upper(), phonetic)
    return text

# Step 2: Define the TTS function with sentence segmentation
def text_to_speech(input_text):
    # Preprocess and segment text
    processed_text = preprocess_text(input_text)
    # Split the processed text by punctuation to form shorter segments
    segments = re.split(r'(?<=[.!?]) +', processed_text)

    # Load speaker embeddings for consistent voice
    embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
    speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

    audio_outputs = []

    # Generate speech for each text segment
    for segment in segments:
        if segment.strip():  # Ensure the segment is not empty
            inputs = processor(text=segment, return_tensors="pt")
            speech = model.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)
            audio_outputs.append(speech.numpy())

    # Concatenate audio from all segments
    complete_speech = np.concatenate(audio_outputs)

    # Save the concatenated speech as a .wav file
    output_file = "speech_output.wav"
    sf.write(output_file, complete_speech, samplerate=16000)

    return output_file

# Step 3: Create Gradio interface
iface = gr.Interface(
    fn=text_to_speech,
    inputs="text",
    outputs="audio",
    title="Fine-tuning TTS for Technical Vocabulary",
    description="Enter text with technical jargon for TTS conversion. The model will handle abbreviations and technical terms for better pronunciation."
)

# Step 4: Launch the app
iface.launch(share=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e28a132cd36df52b3c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e28a132cd36df52b3c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import torch
import torch.nn as nn
import torch.quantization

# Define a simple model
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.fc1 = nn.Linear(10, 10)
        self.fc2 = nn.Linear(10, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Prepare the model for quantization
model = SimpleModel()
model.train()  # Set the model to training mode

# Fuse modules if necessary (e.g., Conv2d + ReLU)
# model = torch.quantization.fuse_modules(model, [['fc1', 'fc2']])

# Specify the quantization configuration
model.qconfig = torch.quantization.get_default_qat_qconfig('fbgemm')

# Prepare the model for QAT
torch.quantization.prepare_qat(model, inplace=True)

# Train your model (placeholder for training code)
# for data in dataloader:
#     output = model(data)
#     loss = loss_fn(output, target)
#     loss.backward()
#     optimizer.step()

# After training, convert the model to a quantized version
quantized_model = torch.quantization.convert(model.eval(), inplace=False)

# Save the quantized model
torch.save(quantized_model.state_dict(), 'quantized_model_qat.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/ao/quantization/observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/ao/quantization/utils.py:407: UserWarning: must run observer before calling calculate_qparams. Returning default values.
#   warnings.warn(
